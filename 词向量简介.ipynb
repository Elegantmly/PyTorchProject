# %% [markdown]
# ## 词向量
# - 学习词向量的概念
# - 用Skip-thought模型训练词向量
# - 学习定义PyTorch模型
# - 学习torch.nn中常见的Module
#     - Embedding
# - 学习常见的PyTorch operations
#     - bmm
#     - logsigmoid
# - 保存和读取PyTorch模型

# %% [markdown]
# **分布式表示**
# 用一个词附近的其他词来表示---现代统计自然语言处理中最有创见的想法之一。
#
# **Word2Vec:Skip-Gram模型**
# 输入一个中心词w(t)，t表示这个词的位置。用一个一层神经网络，预测它周围的单词：w(t-2)、w(t-1)、w(t+1)、w(t+2)，目的并不是为了预测周围的单词，而是为了得到参数，这是一个假任务，真正需要的是参数。
#
# ![Skip-Gram](images/1.png)
# ![Skip-Gram-Loss](images/2.png)
#
# 如果按照模型公式，假如有5w个单词，那么目标函数的分母就会非常大，所以进行修改，进行负例采样，给一个正确的中心词，一个正确的周围词，希望它越大越好。再给一个中心词，和一些错误的周围词，希望它的概率越低越好。
#
# ![Skip-Gram-负例采样](images/3.png)
#
# 第二个式子是目标函数，要越大越好。第一部分是衡量 中心词和附近的词之间的函数，第二部分是衡量k个随机选出不是中心词附近的词和中心词的函数。由于第二部分的点积带负号，所以也是越大越好。所以就这样确定训练目标，然后训练参数。
#
# log后面是sigmoid函数

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as tud

from collections import Counter
import random
import math
import pandas as pd
import scipy
import sklearn
from sklearn.metrics.pairwise import cosine_similarity

USE_CUDA = torch.cuda.is_available()

random.seed(1)
np.random.seed(1)
torch.manual_seed(1)
if USE_CUDA:
    torch.cuda.manual_seed(1)

# 设定一些超参数
C = 3 # context window
K = 100 # number of negative samples
NUM_EPOCHS = 2
MAX_VOCAB_SIZE = 30000
BATCH_SIZE = 128
LEARNING_RATE = 0.2
EMBEDDING_SIZE = 100

def word_tokenize(text):
    return text.split()

# %% [markdown]
# - 从文本文件中读取所有的文字，通过这些文本创建一个vocabulary
# - 由于单词数量可能太大，只选取最常见的MAX_VOCAB_SIZE个单词
# - 我们添加一个UNK单词表示所有不常见的单词
# - 我们需要记录单词到index的mapping、以及index到单词的mapping、单词的count、单词的(normalized)frequency，以及单词总数

# %%
with open("text8/text8.train.txt", "r") as fin:
    text = fin.read()
    
text = text.split()

# 出现频率最高的MAX_VOCAB_SIZE-1个单词,留一个位置给unk(不常见的单词)
vocab = dict(Counter(text).most_common(MAX_VOCAB_SIZE - 1))
vocab["<unk>"] = len(text) - np.sum(list(vocab.values()))

idx_to_word = [word for word in vocab.keys()]
word_to_idx = {word:i for i, word in enumerate(idx_to_word)}
word_to_idx
# Out:
# {'the': 0,
#  'of': 1,
#  'and': 2,
#  'one': 3,
#  'in': 4,
#  'a': 5,
#  'to': 6,
#  'zero': 7,
#  'nine': 8,
#  'two': 9,
#  'is': 10,
#  'as': 11,
#  'eight': 12,
#  'for': 13,
#  's': 14,
#  'five': 15,
#  'three': 16,
#  'was': 17,
#  'by': 18,
#  'that': 19,
#  'four': 20,
#  'six': 21,
#  'seven': 22,
#  'with': 23,
#  'on': 24,
#  'are': 25,
#  'it': 26,
#  'from': 27,
#  'or': 28,
#  'his': 29,
#  'an': 30,
#  'be': 31,
#  'this': 32,
#  'which': 33,
#  'at': 34,
#  'he': 35,
#  'not': 36,
#  'also': 37,
#  'have': 38,
#  'were': 39,
#  'has': 40,
#  'but': 41,
#  'other': 42,
#  'their': 43,
#  'its': 44,
#  'they': 45,
#  'first': 46,
#  'some': 47,
#  'had': 48,
#  'more': 49,
#  'all': 50,
#  'can': 51,
#  'most': 52,
#  'been': 53,
#  'such': 54,
#  'many': 55,
#  'who': 56,
#  'new': 57,
#  'there': 58,
#  'used': 59,
#  'after': 60,
#  'when': 61,
#  'time': 62,
#  'into': 63,
#  'these': 64,
#  'only': 65,
#  'american': 66,
#  'see': 67,
#  'may': 68,
#  'than': 69,
#  'i': 70,
#  'world': 71,
#  'would': 72,
#  'b': 73,
#  'no': 74,
#  'd': 75,
#  'however': 76,
#  'between': 77,
#  'about': 78,
#  'over': 79,
#  'states': 80,
#  'years': 81,
#  'people': 82,
#  'if': 83,
#  'war': 84,
#  'during': 85,
#  'known': 86,
#  'united': 87,
#  'called': 88,
#  'use': 89,
#  'th': 90,
#  'system': 91,
#  'often': 92,
#  'so': 93,
#  'state': 94,
#  'history': 95,
#  'will': 96,
#  'up': 97,
#  'while': 98,
#  'where': 99,
#  'city': 100,
#  'being': 101,
#  'any': 102,
#  'then': 103,
#  'out': 104,
#  'under': 105,
#  'both': 106,
#  'made': 107,
#  'english': 108,
#  'e': 109,
#  'well': 110,
#  'them': 111,
#  'number': 112,
#  'government': 113,
#  'later': 114,
#  'him': 115,
#  'her': 116,
#  'c': 117,
#  'since': 118,
#  'century': 119,
#  'part': 120,
#  'name': 121,
#  'through': 122,
#  'because': 123,
#  'university': 124,
#  'x': 125,
#  'british': 126,
#  'early': 127,
#  'life': 128,
#  'm': 129,
#  'like': 130,
#  'same': 131,
#  'year': 132,
#  'including': 133,
#  'example': 134,
#  'each': 135,
#  'became': 136,
#  'work': 137,
#  'even': 138,
#  'language': 139,
#  'although': 140,
#  'day': 141,
#  'form': 142,
#  'several': 143,
#  'national': 144,
#  'john': 145,
#  'u': 146,
#  'much': 147,
#  'g': 148,
#  'very': 149,
#  'before': 150,
#  'general': 151,
#  'french': 152,
#  'what': 153,
#  't': 154,
#  'against': 155,
#  'n': 156,
#  'those': 157,
#  'high': 158,
#  'links': 159,
#  'now': 160,
#  'could': 161,
#  'based': 162,
#  'second': 163,
#  'another': 164,
#  'great': 165,
#  'f': 166,
#  'do': 167,
#  'large': 168,
#  'external': 169,
#  'list': 170,
#  'modern': 171,
#  'different': 172,
#  'de': 173,
#  'common': 174,
#  'german': 175,
#  'series': 176,
#  'south': 177,
#  'music': 178,
#  'law': 179,
#  'power': 180,
#  'set': 181,
#  'long': 182,
#  'country': 183,
#  'major': 184,
#  'film': 185,
#  'still': 186,
#  'until': 187,
#  'group': 188,
#  'king': 189,
#  'game': 190,
#  'north': 191,
#  'she': 192,
#  'international': 193,
#  'term': 194,
#  'book': 195,
#  'we': 196,
#  'found': 197,
#  'end': 198,
#  'own': 199,
#  'order': 200,
#  'political': 201,
#  'usually': 202,
#  'church': 203,
#  'party': 204,
#  'death': 205,
#  'you': 206,
#  'god': 207,
#  'president': 208,
#  'area': 209,
#  'around': 210,
#  'theory': 211,
#  'include': 212,
#  'way': 213,
#  'did': 214,
#  'though': 215,
#  'ii': 216,
#  'using': 217,
#  'small': 218,
#  'following': 219,
#  'within': 220,
#  'non': 221,
#  'human': 222,
#  'left': 223,
#  'military': 224,
#  'point': 225,
#  'among': 226,
#  'p': 227,
#  'population': 228,
#  'main': 229,
#  'r': 230,
#  'considered': 231,
#  'due': 232,
#  'public': 233,
#  'west': 234,
#  'computer': 235,
#  'information': 236,
#  'family': 237,
#  'important': 238,
#  'right': 239,
#  'east': 240,
#  'popular': 241,
#  'sometimes': 242,
#  'european': 243,
#  'man': 244,
#  'old': 245,
#  'free': 246,
#  'without': 247,
#  'given': 248,
#  'members': 249,
#  'us': 250,
#  'last': 251,
#  'word': 252,
#  'times': 253,
#  'roman': 254,
#  'h': 255,
#  'make': 256,
#  'science': 257,
#  'age': 258,
#  'place': 259,
#  'l': 260,
#  'thus': 261,
#  'case': 262,
#  'does': 263,
#  'house': 264,
#  'languages': 265,
#  'countries': 266,
#  'article': 267,
#  'become': 268,
#  'born': 269,
#  'union': 270,
#  'york': 271,
#  'isbn': 272,
#  'should': 273,
#  'others': 274,
#  'back': 275,
#  'period': 276,
#  'systems': 277,
#  'water': 278,
#  'led': 279,
#  'various': 280,
#  'k': 281,
#  'central': 282,
#  'line': 283,
#  'europe': 284,
#  'st': 285,
#  'few': 286,
#  'began': 287,
#  'generally': 288,
#  'home': 289,
#  'must': 290,
#  'less': 291,
#  'written': 292,
#  'control': 293,
#  'island': 294,
#  'western': 295,
#  'similar': 296,
#  'best': 297,
#  'original': 298,
#  'according': 299,
#  'air': 300,
#  'school': 301,
#  'works': 302,
#  'v': 303,
#  'player': 304,
#  'land': 305,
#  'single': 306,
#  'force': 307,
#  'france': 308,
#  'down': 309,
#  'how': 310,
#  'groups': 311,
#  'england': 312,
#  'development': 313,
#  'official': 314,
#  'rather': 315,
#  'greek': 316,
#  'space': 317,
#  'j': 318,
#  'support': 319,
#  'germany': 320,
#  'london': 321,
#  'data': 322,
#  'km': 323,
#  'named': 324,
#  'published': 325,
#  'just': 326,
#  'said': 327,
#  'black': 328,
#  'games': 329,
#  'every': 330,
#  'late': 331,
#  'christian': 332,
#  'short': 333,
#  'body': 334,
#  'off': 335,
#  'earth': 336,
#  'empire': 337,
#  'o': 338,
#  'economic': 339,
#  'college': 340,
#  'army': 341,
#  'company': 342,
#  'either': 343,
#  'social': 344,
#  'version': 345,
#  'million': 346,
#  'kingdom': 347,
#  'court': 348,
#  'field': 349,
#  'standard': 350,
#  'along': 351,
#  'service': 352,
#  'sea': 353,
#  'developed': 354,
#  'means': 355,
#  'america': 356,
#  'result': 357,
#  'light': 358,
#  'never': 359,
#  'today': 360,
#  'team': 361,
#  'especially': 362,
#  'held': 363,
#  'society': 364,
#  'further': 365,
#  'character': 366,
#  'take': 367,
#  'third': 368,
#  'forces': 369,
#  'open': 370,
#  'books': 371,
#  'republic': 372,
#  'possible': 373,
#  'fact': 374,
#  'men': 375,
#  'show': 376,
#  'took': 377,
#  'battle': 378,
#  'good': 379,
#  'children': 380,
#  'natural': 381,
#  'son': 382,
#  'having': 383,
#  'present': 384,
#  'himself': 385,
#  'current': 386,
#  'former': 387,
#  'local': 388,
#  'person': 389,
#  'process': 390,
#  'islands': 391,
#  'words': 392,
#  'white': 393,
#  'little': 394,
#  'above': 395,
#  'near': 396,
#  'father': 397,
#  'total': 398,
#  'soviet': 399,
#  'itself': 400,
#  'side': 401,
#  'upon': 402,
#  'red': 403,
#  'seen': 404,
#  'culture': 405,
#  'references': 406,
#  'play': 407,
#  'days': 408,
#  'river': 409,
#  'came': 410,
#  'level': 411,
#  'certain': 412,
#  'largest': 413,
#  'press': 414,
#  'once': 415,
#  'created': 416,
#  'famous': 417,
#  'jewish': 418,
#  'almost': 419,
#  'full': 420,
#  'james': 421,
#  'software': 422,
#  'numbers': 423,
#  'al': 424,
#  'role': 425,
#  'january': 426,
#  'region': 427,
#  'site': 428,
#  'member': 429,
#  'areas': 430,
#  'image': 431,
#  'story': 432,
#  'religious': 433,
#  'community': 434,
#  'again': 435,
#  'ancient': 436,
#  'act': 437,
#  'art': 438,
#  'real': 439,
#  'played': 440,
#  'related': 441,
#  'view': 442,
#  'league': 443,
#  'movement': 444,
#  'rights': 445,
#  'production': 446,
#  'terms': 447,
#  'center': 448,
#  'low': 449,
#  'energy': 450,
#  'foreign': 451,
#  'died': 452,
#  'council': 453,
#  'change': 454,
#  'type': 455,
#  'source': 456,
#  'research': 457,
#  'living': 458,
#  'december': 459,
#  'produced': 460,
#  'class': 461,
#  'canada': 462,
#  'bc': 463,
#  'particular': 464,
#  'making': 465,
#  'head': 466,
#  'william': 467,
#  'latin': 468,
#  'northern': 469,
#  'forms': 470,
#  'design': 471,
#  'minister': 472,
#  'style': 473,
#  'david': 474,
#  'available': 475,
#  'civil': 476,
#  'japanese': 477,
#  'next': 478,
#  'special': 479,
#  'position': 480,
#  'program': 481,
#  'w': 482,
#  'march': 483,
#  'far': 484,
#  'women': 485,
#  'chinese': 486,
#  'released': 487,
#  'established': 488,
#  'y': 489,
#  'television': 490,
#  'george': 491,
#  'together': 492,
#  'eastern': 493,
#  'function': 494,
#  'hand': 495,
#  'middle': 496,
#  'july': 497,
#  'charles': 498,
#  'might': 499,
#  'parts': 500,
#  'china': 501,
#  'instead': 502,
#  'code': 503,
#  'band': 504,
#  'built': 505,
#  'thought': 506,
#  'least': 507,
#  'india': 508,
#  'included': 509,
#  'study': 510,
#  'meaning': 511,
#  'emperor': 512,
#  'june': 513,
#  'half': 514,
#  'text': 515,
#  'always': 516,
#  'anti': 517,
#  'range': 518,
#  'actor': 519,
#  'trade': 520,
#  'per': 521,
#  'final': 522,
#  'traditional': 523,
#  'capital': 524,
#  'uk': 525,
#  'young': 526,
#  'taken': 527,
#  'prime': 528,
#  'november': 529,
#  'economy': 530,
#  'nature': 531,
#  'october': 532,
#  'august': 533,
#  'lost': 534,
#  'players': 535,
#  'april': 536,
#  'addition': 537,
#  'spanish': 538,
#  'uses': 539,
#  'live': 540,
#  'run': 541,
#  'true': 542,
#  'recent': 543,
#  'value': 544,
#  'project': 545,
#  'wrote': 546,
#  'effect': 547,
#  'technology': 548,
#  'september': 549,
#  'evidence': 550,
#  'southern': 551,
#  'catholic': 552,
#  'note': 553,
#  'historical': 554,
#  'radio': 555,
#  'whose': 556,
#  'album': 557,
#  'model': 558,
#  'top': 559,
#  'italian': 560,
#  'africa': 561,
#  'self': 562,
#  'rule': 563,
#  'won': 564,
#  'australia': 565,
#  'done': 566,
#  'particularly': 567,
#  'themselves': 568,
#  'philosophy': 569,
#  'cases': 570,
#  'influence': 571,
#  'species': 572,
#  'structure': 573,
#  'rate': 574,
#  'subject': 575,
#  'record': 576,
#  'nations': 577,
#  'russian': 578,
#  'referred': 579,
#  'our': 580,
#  'below': 581,
#  'love': 582,
#  'throughout': 583,
#  'continued': 584,
#  'problem': 585,
#  'star': 586,
#  'japan': 587,
#  'whether': 588,
#  'therefore': 589,
#  'education': 590,
#  'rock': 591,
#  'song': 592,
#  'israel': 593,
#  'irish': 594,
#  'come': 595,
#  'names': 596,
#  'title': 597,
#  'higher': 598,
#  'films': 599,
#  'town': 600,
#  'too': 601,
#  'com': 602,
#  'jews': 603,
#  'action': 604,
#  'originally': 605,
#  'february': 606,
#  'individual': 607,
#  'cities': 608,
#  'paul': 609,
#  'strong': 610,
#  'elements': 611,
#  'market': 612,
#  'football': 613,
#  'my': 614,
#  'here': 615,
#  'sound': 616,
#  'network': 617,
#  'eventually': 618,
#  'est': 619,
#  'independent': 620,
#  'author': 621,
#  'described': 622,
#  'base': 623,
#  'despite': 624,
#  'problems': 625,
#  'characters': 626,
#  'robert': 627,
#  'female': 628,
#  'la': 629,
#  'food': 630,
#  'internet': 631,
#  'able': 632,
#  'formed': 633,
#  'practice': 634,
#  're': 635,
#  'office': 636,
#  'royal': 637,
#  'complex': 638,
#  'commonly': 639,
#  'events': 640,
#  'fiction': 641,
#  'parliament': 642,
#  'received': 643,
#  'season': 644,
#  'key': 645,
#  'lower': 646,
#  'african': 647,
#  'writer': 648,
#  'legal': 649,
#  'outside': 650,
#  'typically': 651,
#  'complete': 652,
#  'followed': 653,
#  'significant': 654,
#  'page': 655,
#  'basic': 656,
#  'actually': 657,
#  'includes': 658,
#  'business': 659,
#  'aircraft': 660,
#  'widely': 661,
#  'scientific': 662,
#  'beginning': 663,
#  'male': 664,
#  'laws': 665,
#  'physical': 666,
#  'types': 667,
#  'deaths': 668,
#  'building': 669,
#  'henry': 670,
#  'future': 671,
#  'leader': 672,
#  'material': 673,
#  'went': 674,
#  'cannot': 675,
#  'britain': 676,
#  'news': 677,
#  'get': 678,
#  'simply': 679,
#  'cross': 680,
#  'ever': 681,
#  'ireland': 682,
#  'services': 683,
#  'industry': 684,
#  'fire': 685,
#  'elected': 686,
#  'close': 687,
#  'method': 688,
#  'specific': 689,
#  'cause': 690,
#  'defined': 691,
#  'canadian': 692,
#  'go': 693,
#  'believe': 694,
#  'examples': 695,
#  'writing': 696,
#  'california': 697,
#  'post': 698,
#  'mass': 699,
#  'births': 700,
#  'size': 701,
#  'lead': 702,
#  'video': 703,
#  'return': 704,
#  'knowledge': 705,
#  'independence': 706,
#  'idea': 707,
#  'points': 708,
#  'organization': 709,
#  'associated': 710,
#  'personal': 711,
#  'sense': 712,
#  'soon': 713,
#  'classical': 714,
#  'introduced': 715,
#  'required': 716,
#  'majority': 717,
#  'movie': 718,
#  'concept': 719,
#  'designed': 720,
#  'yet': 721,
#  'away': 722,
#  'changes': 723,
#  'believed': 724,
#  'located': 725,
#  'co': 726,
#  'county': 727,
#  'studies': 728,
#  'religion': 729,
#  'lord': 730,
#  'blue': 731,
#  'indian': 732,
#  'rules': 733,
#  'find': 734,
#  'features': 735,
#  'started': 736,
#  'mother': 737,
#  'put': 738,
#  'currently': 739,
#  'ball': 740,
#  'working': 741,
#  'policy': 742,
#  'russia': 743,
#  'earlier': 744,
#  'election': 745,
#  'thomas': 746,
#  'sources': 747,
#  'brought': 748,
#  'provide': 749,
#  'allowed': 750,
#  'association': 751,
#  'things': 752,
#  'greater': 753,
#  'online': 754,
#  'australian': 755,
#  'attack': 756,
#  'added': 757,
#  'across': 758,
#  'founded': 759,
#  'relations': 760,
#  'object': 761,
#  'limited': 762,
#  'mostly': 763,
#  'federal': 764,
#  'effects': 765,
#  'interest': 766,
#  'z': 767,
#  'probably': 768,
#  'reference': 769,
#  'past': 770,
#  'career': 771,
#  'security': 772,
#  'stories': 773,
#  'need': 774,
#  'your': 775,
#  'simple': 776,
#  'gave': 777,
#  'constitution': 778,
#  'park': 779,
#  'letter': 780,
#  'remains': 781,
#  'me': 782,
#  'success': 783,
#  'longer': 784,
#  'growth': 785,
#  'killed': 786,
#  'say': 787,
#  'give': 788,
#  'chief': 789,
#  'definition': 790,
#  'media': 791,
#  'wide': 792,
#  'night': 793,
#  'letters': 794,
#  'leading': 795,
#  'website': 796,
#  'library': 797,
#  'contains': 798,
#  'green': 799,
#  'remained': 800,
#  'etc': 801,
#  'largely': 802,
#  'color': 803,
#  'moved': 804,
#  'months': 805,
#  'spain': 806,
#  'dead': 807,
#  'big': 808,
#  'better': 809,
#  'larger': 810,
#  'already': 811,
#  'perhaps': 812,
#  'novel': 813,
#  'speed': 814,
#  'peace': 815,
#  'holy': 816,
#  'help': 817,
#  'territory': 818,
#  'cell': 819,
#  'parties': 820,
#  'cultural': 821,
#  'politics': 822,
#  'origin': 823,
#  'companies': 824,
#  'lake': 825,
#  'private': 826,
#  'claim': 827,
#  'saint': 828,
#  'iii': 829,
#  'wife': 830,
#  'saw': 831,
#  'dutch': 832,
#  'revolution': 833,
#  'appeared': 834,
#  'refer': 835,
#  'matter': 836,
#  'makes': 837,
#  'whole': 838,
#  'lines': 839,
#  'era': 840,
#  'directly': 841,
#  'separate': 842,
#  'products': 843,
#  'italy': 844,
#  'results': 845,
#  'produce': 846,
#  'surface': 847,
#  'asia': 848,
#  'highly': 849,
#  'caused': 850,
#  'attempt': 851,
#  'authority': 852,
#  'double': 853,
#  'coast': 854,
#  'status': 855,
#  'alexander': 856,
#  'successful': 857,
#  'health': 858,
#  'turn': 859,
#  'literature': 860,
#  'towards': 861,
#  'playing': 862,
#  'direct': 863,
#  'oil': 864,
#  'blood': 865,
#  'richard': 866,
#  'singer': 867,
#  'latter': 868,
#  'whom': 869,
#  'primary': 870,
#  'treaty': 871,
#  'division': 872,
#  'becomes': 873,
#  'basis': 874,
#  'analysis': 875,
#  'date': 876,
#  'enough': 877,
#  'married': 878,
#  'edition': 879,
#  'chemical': 880,
#  'exist': 881,
#  'nation': 882,
#  'prize': 883,
#  'issues': 884,
#  'native': 885,
#  'programming': 886,
#  'likely': 887,
#  'commercial': 888,
#  'property': 889,
#  'release': 890,
#  'web': 891,
#  'amount': 892,
#  'allow': 893,
#  'course': 894,
#  'reason': 895,
#  'machine': 896,
#  'provided': 897,
#  'sun': 898,
#  'smaller': 899,
#  'money': 900,
#  'museum': 901,
#  'digital': 902,
#  'functions': 903,
#  'jesus': 904,
#  'divided': 905,
#  'average': 906,
#  'replaced': 907,
#  'metal': 908,
#  'length': 909,
#  'degree': 910,
#  'gas': 911,
#  'peter': 912,
#  'tradition': 913,
#  'memory': 914,
#  'claims': 915,
#  'nearly': 916,
#  'tv': 917,
#  'washington': 918,
#  'access': 919,
#  'difficult': 920,
#  'rome': 921,
#  'notable': 922,
#  'ground': 923,
#  'medical': 924,
#  'queen': 925,
#  'claimed': 926,
#  'mid': 927,
#  'recently': 928,
#  'ten': 929,
#  'records': 930,
#  'collection': 931,
#  'animals': 932,
#  'involved': 933,
#  'schools': 934,
#  'read': 935,
#  'finally': 936,
#  'front': 937,
#  'sent': 938,
#  'performance': 939,
#  'variety': 940,
#  'changed': 941,
#  'director': 942,
#  'elections': 943,
#  'frequently': 944,
#  'liberal': 945,
#  'congress': 946,
#  'entire': 947,
#  'hard': 948,
#  'highest': 949,
#  'methods': 950,
#  'club': 951,
#  'democratic': 952,
#  'mark': 953,
#  'ideas': 954,
#  'product': 955,
#  'don': 956,
#  'served': 957,
#  'christ': 958,
#  'programs': 959,
#  'section': 960,
#  'increased': 961,
#  'louis': 962,
#  'call': 963,
#  'board': 964,
#  'relationship': 965,
#  'bbc': 966,
#  'students': 967,
#  'michael': 968,
#  'relatively': 969,
#  'discovered': 970,
#  'element': 971,
#  'conditions': 972,
#  'objects': 973,
#  'increase': 974,
#  'unit': 975,
#  'actress': 976,
#  'child': 977,
#  'appear': 978,
#  'returned': 979,
#  'existence': 980,
#  'rest': 981,
#  'appears': 982,
#  'map': 983,
#  'fall': 984,
#  'musical': 985,
#  'know': 986,
#  'minor': 987,
#  'baseball': 988,
#  'adopted': 989,
#  'orthodox': 990,
#  'except': 991,
#  'assembly': 992,
#  'nuclear': 993,
#  'user': 994,
#  'takes': 995,
#  'san': 996,
#  'event': 997,
#  'hall': 998,
#  'heavy': 999,
#  ...}

# %%
word_counts = np.array([count for count in vocab.values()], dtype = np.float32)
word_freqs = word_counts / np.sum(word_counts)
print(word_counts)
# 把概率全都提到3/4次方，然后再重新normalize
# 3/4次之后，会将高概率的单词的概率值，分一部分给低概率的单词。
# 因为相同的操作，对高概率单词的概率值影响更大
word_freqs = word_freqs ** (3./4.)

# 词频3/4次方以后，词频和不为1了，所以重新normalize一下
word_freqs = word_freqs / np.sum(word_freqs)
VOCAB_SIZE = len(idx_to_word)
# Out:
# [9.59616e+05 5.37144e+05 3.76233e+05 ... 2.00000e+01 2.00000e+01
#  6.17240e+05]

# %% [markdown]
# ### 实现Dataloader
#
# dataloader可以自动生成batch
#
# 一个dataloader需要以下内容：
# - 把所有text编码成数字，然后用subsampling预处理这些文字
# - 保存vocabulary，单词count，normalized word frequency
# - 每个iteration sample一个中心词
# - 根据当前的中心词返回context单词
# - 根据中心词sample一些negative单词
# - 返回单词的counts
#
# 为了使用dataloader，需要定义以下两个function：
# -  ```__len__function``` 需要返回整个数据集中有多少个item
# -  ```__get__``` 根据给定的index返回一个item
#
# 有了dataloader之后，可以轻松随机打乱整个数据集，拿到一个batch的数据等等

# %% [markdown]
# ### Dataset和Dataloader
#
# 简单说，用 一个类 抽象地表示数据集，而 Dataloader 作为迭代器，每次产生一个 batch 大小的数据，节省内存。
#
# Dataset 是 PyTorch 中用来表示数据集的一个抽象类，我们的数据集可以用这个类来表示，至少覆写下面两个方法即可：
# - ```__len__```：数据集大小
# - ```__getitem__```:实现这个方法后，可以通过下标的方式(dataset[i] )的来取得第 i 个数据

# %%
class WordEmbeddingDataset(tud.Dataset):
    def __init__(self, text, word_to_idx, idx_to_word, word_freqs, word_counts):
        super(WordEmbeddingDataset, self).__init__()
        self.text_encoded = [word_to_idx.get(word, word_to_idx["<unk>"]) for word in text]
        self.text_encoded = torch.LongTensor(self.text_encoded)
        self.word_to_idx = word_to_idx
        self.idx_to_word = idx_to_word
        self.word_freqs = torch.Tensor(word_freqs)
        self.word_counts = torch.Tensor(word_counts)
        
    def __len__(self):
        # 这个数据集一共有多少个item
        return len(self.text_encoded)
        
    def __getitem__(self, idx): 
        # 首先要返回idx所对应的中心词
        center_word = self.text_encoded[idx]
        
        # 周围词 range防止小于0 余数防止越界
        pos_indices = list(range(idx-C, idx)) + list(range(idx+1, idx+C+1))
        
        pos_indices = [i % len(self.text_encoded) for i in pos_indices]
        
        pos_words = self.text_encoded[pos_indices]
        
        # 随机产生不在周围的词 负例采样单词
        # 在三万个单词，根据freqs做采样，返回的是下标，对每个正确的单词采样k个不正确的单词
        neg_words = torch.multinomial(self.word_freqs, K * pos_words.shape[0], True)
        
        return center_word, pos_words, neg_words

# %% [markdown]
# 创建dataset和dataloader

# %%
dataset = WordEmbeddingDataset(text, word_to_idx, idx_to_word, word_freqs, word_counts)
dataloader = tud.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle = True, num_workers = 0)

# %%
dataset.text_encoded[:100]
# Out:
# tensor([ 4813,  3139,    11,     5,   194,     1,  3015,    46,    59,   155,
#           127,   741,   461, 10485,   133,     0, 25752,     1,     0,   108,
#           833,     2,     0, 16267, 29999,     1,     0,   152,   833,  3493,
#             0,   194,    10,   186,    59,     4,     5, 10620,   213,     6,
#          1332,   102,   437,    19,    59,  2764,   355,     6,  3625,     0,
#           709,     1,   364,    26,    40,    37,    53,   527,    97,    11,
#             5,  1398,  2929,    18,   562,   691,  6644,     0,   252,  4813,
#            10,  1043,    27,     0,   316,   247, 29999,  2964,   789,   189,
#          4813,    11,     5,   201,   569,    10,     0,  1107,    19,  2581,
#            25,  8819,     2,   273,    31,  4089,   140,    58,    25,  6494])

# %%
next(iter(dataloader))
# Out:
# [tensor([ 2233,     4,   561,   119,  1586,  8470,   390,    15,  1390,   285,
#              1,    21,    47, 29999,     1,  3021,  1247,   424,     4,  2663,
#            408,     0,     0,   140,    11,    15,  1167,  2480,     3,   784,
#           1665, 12015, 13367,     4,    16,  1764,  4905,    42,    71,     0,
#            113,     7,    16,    45,  1086,   758,    95,  8825,     2,  1421,
#           1465,     2,   706,  3333,    18,     0,   195,  4586,    18,    23,
#             27,    27,    11,   522,  2629,    18,  1385,   156,  7448,     8,
#            115,  1392,     0,  1077,   339,  2669,  3677,    15,    36,  3990,
#           2588,    26,    88,  9680,    13,  3337,     1,    11,     6,  2965,
#              6,  1255, 12705,     8,  4866,     0,  4560,   336,   376,    31,
#          29999,    10,   728,  1730,  3385,  2609, 19043,   484,    15,    55,
#           1057,    45,     0,    30,  2598,  2986,     8,    38,   353,  2336,
#           5195, 29999,  1218,   196,     7,   808,    13,   347]),
#  tensor([[   13,     0,  1777,    33,  7314,    24],
#          [    0,  9815,    10,   439,   128,    67],
#          [29999, 29999,   191,     4,   464,  6018],
#          [    9,     7,    90,    32,   209,    17],
#          [    1,    44,  1407,    24,  1922,  9975],
#          [    1,     0,    71,  4882,  2291,    27],
#          [    5,  1741, 20075,  1316,  3323,  4684],
#          [  103, 29999,     6, 15353,    34,     0],
#          [  428,     1,     0,   672, 29999,   636],
#          [ 3736,     9,     3,   119,  3736,   249],
#          [  369,  4007,  1065,   245,   399,  6081],
#          [   20,     3,    12,    22, 13032,   533],
#          [   98,   724,    18,     6,    31,   650],
#          [   83,    45,    51,   770,     0,  2663],
#          [    0,  3527,   644,   808,  1004,    34],
#          [    9,     7,   914,    70,   109,     3],
#          [   12,    22,    12, 29999,  2843,  1464],
#          [    0,   100,     1, 29999, 29999,    33],
#          [    0,  4278,  7601,     3,     8,     3],
#          [    0,   251,   175,     1,    71,    84],
#          [   13,   326,     8,     3,    12,    20],
#          [12533,   377,   275,   180,    45,    75],
#          [ 7605,     2, 29201,  1933,   400,    10],
#          [ 1862,   983,   465,    42, 29999,     1],
#          [  387,   253,  6820,     5,  2919,     6],
#          [25466,    20,     3,   254,   552,   203],
#          [    0,  1062,     1,     2,    44,    89],
#          [    5,   394,  1517,     0,  1260,   100],
#          [ 7399,  4751,     9,   438,    18,  5415],
#          [  909,     1,     0,   120,   103,     0],
#          [ 1886,     4,    94,     2,  6625, 23709],
#          [   19,    40,    53,   583,     0,    95],
#          [ 4785,     1,  1414,     5,    62,    13],
#          [ 2379,  3881,   928,     9,     7,     7],
#          [    9,     7,     7,   619,   406,  4585],
#          [    1,    29, 26933,    17, 12574, 29999],
#          [ 4079,     2,  2335,     6,  4905,  3098],
#          [    1, 11097,     2,   322,    61, 21070],
#          [    6,  6659,    85,    84,    70,    99],
#          [ 1450,   113,  4332,   530,   781,   610],
#          [   16,  3680,    14,  1476,    65,     5],
#          [   78,    20,     7,     7,    81,  2415],
#          [    3,    12,    12,  5073,   873,     0],
#          [  788,    97,   123,    38,     5,   948],
#          [ 2468,    33, 29999,    19,  7473,  1376],
#          [ 1041,    25,   350,     0,   172,   667],
#          [ 2340,     4,   649,     0,   127,    22],
#          [29999,  1130,  1150,  5214, 29999, 29839],
#          [    4,     0,   496,     5,  1568,     4],
#          [  185,   564,     0,  1027,    13,   297],
#          [   20,  1069,  6721,     3,     9,    22],
#          [ 3527,    60, 29999,  1289,    60, 29999],
#          [  110,    11,     0,   209,    13,   210],
#          [ 1568,    13, 18618,    11,   415,    45],
#          [  180,     1,   320,    32,   213,     9],
#          [   30, 15592,  1799, 28120,    39,   324],
#          [   29,  5531,    24,  2999,     0,    46],
#          [ 1505,     5,  9436,   963,    17,   107],
#          [   17, 17592,  1356,  7434,    56,  1425],
#          [21439,  1959,   385,     0,  5405,     1],
#          [    1,     0,  1457,     5,   703,  3413],
#          [    5, 23055,   910, 20244,   124,     4],
#          [  892,     1,   900,     0,   262,    10],
#          [18979,     4,    32,  1711,    96,    31],
#          [29999,    56,    17,    18,  2285,     4],
#          [ 9960,     1,  4771,  3227, 18066,  2431],
#          [   18,     0,  8118,    32,  5222,     0],
#          [ 7539,     1,  5624,    10,     0,   307],
#          [    0,  3239,    32,  2159,    96,  4700],
#          [  212,     0,     3,     8,     7, 29999],
#          [ 8317, 13675, 11309,    11,    30,   621],
#          [  664,  1392,   628,    67,    37,  2388],
#          [15146,    13,   134,   481, 29999,     2],
#          [ 5987,    40,   143,     1,   201, 22786],
#          [  204,     6,     0,   480,    19,    35],
#          [   19,   793,    10,    18,  1192,    11],
#          [ 4108,  7734,  2043,  7207,  3316,  2337],
#          [  118,     3,     8,    20,   739,  2619],
#          [    2,  3664,    68,  1861,  4807,  1189],
#          [ 6170,    13,   815,     4,    68,     9],
#          [   21,     7,     7,     4,    44,     3],
#          [   11,   196,   986,   360,    23,     0],
#          [   25,    47,    93, 16170,  1495,    19],
#          [    8,     8,    22,  2230,   272,     7],
#          [ 5798,    28, 23236, 15936,   611,   106],
#          [ 1618,     0,  3707,  2683,  1841,     2],
#          [ 3662,     0, 11568, 29999,    24,     0],
#          [  208,     2, 29999,  1814,   208,    67],
#          [   88,   104, 29999,   116, 29999, 29999],
#          [ 4137,   628,  3977,   830,     1, 29999],
#          [    0,  1329,   708,  1337,     0,   395],
#          [25753,   534,    46, 11499,     3,     8],
#          [29999,    10,     5,  8908,     1,     0],
#          [  532,     3,     8,     8,     6, 11661],
#          [29999,   362,   238,    38,    53,   197],
#          [ 2461,   547,     1,   304,  1806,     5],
#          [  112,     1,     0,   228,  1354,     0],
#          [  336,  6866,   526,  6866,   729,     2],
#          [   24,     0, 10083, 29999,    23,  4000],
#          [    0,  3655,    96,  5926,  1080,  3448],
#          [ 2863,    19, 15092, 20371,    64,  2594],
#          [   27,  5824,    19,    46, 29999,     2],
#          [ 8922,     1,  1528,     3,    20,     9],
#          [ 3560,   586,  4374,    66,   490,  1730],
#          [29999,   175, 29999,     1,     0,  1164],
#          [ 7130,     4,  1307,    35,    17,     0],
#          [11850,  5191, 14652,  8906,  9977,  7267],
#          [  616,  1216,   160,    49,  2669,    45],
#          [   20,     3,     8,     8, 29999,  1325],
#          [   10,   373,    19,   657, 29999,    11],
#          [  334,  1328,    13,   106,  2550,     2],
#          [ 7138,     5,  7117,    51,    38,     3],
#          [  747,   202,  4452,  2050,  3386,   228],
#          [    4,   175,  1978,   134,    72,    31],
#          [ 7915,  3591,     4,   227,  1048,     1],
#          [   35,    17,   362,    18,   498, 29999],
#          [    4,     3,     8,    15,  4269,  7586],
#          [ 1105,    64,  1446,   750,    13,    55],
#          [19266,     0,  2723,   615,  4704,   633],
#          [  659,  1300,     2,     6,    43,  8124],
#          [    0,    71,     0, 23347,    49,    69],
#          [29999,  1284, 29999, 29999,   279,    18],
#          [ 6451, 29999,  3535, 29999,    17, 14648],
#          [    3,    15,    50,   986,     1,    29],
#          [   15,   117,    15,   166,     6,    21],
#          [  460,     4,     0,  5623,  3699, 12822],
#          [    0,   205,   574,  1535,   369,     6],
#          [    4,     0,    87,     3,     8,     8]]),
#  tensor([[   25,  9694,    41,  ...,    30,   359,    22],
#          [    1,  1100,  8080,  ...,    49,   673,  8126],
#          [ 4911,  1684,    75,  ...,     9,   381, 14378],
#          ...,
#          [ 3260,   247,   534,  ...,   874,  8746,    23],
#          [ 3829,    80, 27548,  ...,  8552, 18512, 18240],
#          [ 3120,   353,  7182,  ..., 10786, 12792,     5]])]

# %% [markdown]
# ### 定义PyTorch模型

# %%
class EmbeddingModel(nn.Module):
    def __init__(self, vocab_size, embed_size):
        super(EmbeddingModel, self).__init__()
        
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        
        # nn.Embedding
        # 给一个编号，嵌入层就能返回这个编号对应的嵌入向量
        # 输入为一个编号列表，输出为对应的符号嵌入向量列表
        # num_embeddings :词典的大小尺寸
        # embedding_dim :嵌入向量的维度，即用多少维来表示一个符号。
        self.in_embed = nn.Embedding(self.vocab_size, self.embed_size)
        self.out_embed = nn.Embedding(self.vocab_size, self.embed_size)
    
    def forward(self, input_labels, pos_labels, neg_labels):
        # input_labels: [batch_size] 中心词
        # pos_labels: [batch_size, (window_size * 2)] 周围词
        # neg_labels: [batch_size], (window_size * 2 * K) 非周围词
        
        # batch是128个数字,把每一个数字embed成vector
        input_embedding = self.in_embed(input_labels) # [batch_size , embed_size]
        pos_embedding = self.out_embed(pos_labels) # [batch_size,  (window_size * 2), embed_size]
        neg_embedding = self.out_embed(neg_labels) # [batch_size,  (window_size * 2 * K), embed_size]
        
        
        input_embedding = input_embedding.unsqueeze(2) # 增加tensor的维度 [batch_size , embed_size, 1]
        
        # loss里面说要做一个点乘，
        # bmm: (b,n,m) x (b,m,p) = (b,n,p)
        pos_dot = torch.bmm(pos_embedding, input_embedding).squeeze(2) # [batch_size, (window_size * 2), 1]
        neg_dot = torch.bmm(neg_embedding, -input_embedding).squeeze(2) # [batch_size, (window_size * 2 * k), 1]
        
        
        log_pos = F.logsigmoid(pos_dot).sum(1) # 在第一维上求和
        log_neg = F.logsigmoid(neg_dot).sum(1)
        
        loss = log_pos + log_neg
        
        # loss当前是一个objective function,并不是一个loss，返回负的
        return -loss # [batch_size]
        
    
    def input_embeddings(self):
        return self.in_embed.weight.data.cpu.numpy()

# %% [markdown]
# 定义一个模型以及把模型移动到GPU

# %%
model = EmbeddingModel(VOCAB_SIZE, EMBEDDING_SIZE)
if USE_CUDA:
    model = model.cuda()

# %% [markdown]
# 下面是评估模型的代码，以及训练模型的代码
#
# 训练模型：
# - 模型一般需要训练若干个epoch
# - 每个epoch我们都把所有的数据分成若干个batch
# - 把每个batch的输入和输出都包装成cuda tensor
# - forward pass，通过输入的句子预测每个单词的下一个单词
# - 用模型的预测和正确的下一个单词计算cross entropy loss
# - 清空模型当前gradient
# - backward pass
# - 更新模型参数
# - 每隔一定的iteration输出模型在当前iteration的loss，以及在验证数据集上做模型的评估

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE)
for e in range(NUM_EPOCHS):
    for i, [input_labels, pos_labels, neg_labels] in enumerate(dataloader):
        input_labels = input_labels.long()
        pos_labels = pos_labels.long()
        neg_labels = neg_labels.long()
        if USE_CUDA:
            input_labels = input_labels.cuda()
            pos_labels = pos_labels.cuda()
            neg_labels = neg_labels.cuda()
            
            optimizer.zero_grad()
            loss = model(input_labels, pos_labels, neg_labels).mean() # 求个平均，返回的是若干个loss
            loss.backward()
            optimizer.step()
            
            if i % 100 == 0:
                print("epoch", e, "iteration", i, loss.item())
# Out:
# epoch 0 iteration 0 2400.27685546875
# epoch 0 iteration 100 1235.7406005859375
# epoch 0 iteration 200 873.1128540039062
# epoch 0 iteration 300 781.069580078125
# epoch 0 iteration 400 636.6002197265625
# epoch 0 iteration 500 579.11865234375
# epoch 0 iteration 600 507.3105773925781
# epoch 0 iteration 700 453.44580078125
# epoch 0 iteration 800 433.0643310546875
# epoch 0 iteration 900 375.1482849121094
# epoch 0 iteration 1000 313.5187683105469
# epoch 0 iteration 1100 383.52899169921875
# epoch 0 iteration 1200 292.67230224609375
# epoch 0 iteration 1300 269.2372131347656
# epoch 0 iteration 1400 284.4329833984375
# epoch 0 iteration 1500 257.2510986328125
# epoch 0 iteration 1600 307.3775939941406
# epoch 0 iteration 1700 259.46124267578125
# epoch 0 iteration 1800 173.3792266845703
# epoch 0 iteration 1900 230.35145568847656
# epoch 0 iteration 2000 199.69741821289062
# epoch 0 iteration 2100 179.59371948242188
# epoch 0 iteration 2200 175.15467834472656
# epoch 0 iteration 2300 198.58416748046875
# epoch 0 iteration 2400 246.36123657226562
# epoch 0 iteration 2500 151.16867065429688
# epoch 0 iteration 2600 207.65487670898438
# epoch 0 iteration 2700 216.19940185546875
# epoch 0 iteration 2800 149.59075927734375
# epoch 0 iteration 2900 120.72554016113281
# epoch 0 iteration 3000 207.4307861328125
# epoch 0 iteration 3100 116.12150573730469
# epoch 0 iteration 3200 179.87973022460938
# epoch 0 iteration 3300 146.9888916015625
# epoch 0 iteration 3400 116.69430541992188
# epoch 0 iteration 3500 121.3989028930664
